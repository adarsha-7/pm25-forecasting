# %%
import pandas as pd
from sklearn.linear_model import Lasso
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
import time

# %%
X_train = pd.read_csv("../../../data/processed/1_hour_prediction/X_train_linear.csv")
X_test  = pd.read_csv("../../../data/processed/1_hour_prediction/X_test_linear.csv")
y_train = pd.read_csv("../../../data/processed/1_hour_prediction/y_train.csv").squeeze()
y_test  = pd.read_csv("../../../data/processed/1_hour_prediction/y_test.csv").squeeze()

# %%
import numpy as np

alphas = [0.0001, 0.001, 0.01, 0.05, 0.1, 0.25, 0.5, 1.0, 2.0, 5.0, 10.0]

results = []
for alpha in alphas:
    lasso = Lasso(alpha=alpha)
    lasso.fit(X_train, y_train)
    y_pred = lasso.predict(X_test)

    rmse = root_mean_squared_error(y_test, y_pred)
    mae  = mean_absolute_error(y_test, y_pred)
    r2   = r2_score(y_test, y_pred)

    n_nonzero = np.sum(lasso.coef_ != 0)

    results.append({
        "alpha": alpha,
        "rmse": rmse,
        "mae": mae,
        "r2": r2,
        "n_nonzero_coefs": n_nonzero,
    })
# Out:
# d:\projects\pm25-forecasting\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.043e+04, tolerance: 3.239e+02
#   model = cd_fast.enet_coordinate_descent(
# d:\projects\pm25-forecasting\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.787e+04, tolerance: 3.239e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
for result in results:
    print(f"alpha: {result["alpha"]}     rmse:{result["rmse"]}     mae:{result["mae"]}     r2:{result["r2"]}    n_nonzero:{result["n_nonzero_coefs"]}")
# Out:
# alpha: 0.0001     rmse:6.699136891710515     mae:3.6238190384593607     r2:0.949798328479605    n_nonzero:125
# alpha: 0.001     rmse:6.713031978540679     mae:3.613541791470863     r2:0.9495898598310825    n_nonzero:117
# alpha: 0.01     rmse:6.904442505461918     mae:3.621102547520605     r2:0.9466741596623894    n_nonzero:73
# alpha: 0.05     rmse:7.323074702187051     mae:3.6994188419941993     r2:0.9400115830017408    n_nonzero:41
# alpha: 0.1     rmse:7.474052982545039     mae:3.6879355741845035     r2:0.9375125478281806    n_nonzero:25
# alpha: 0.25     rmse:7.645368140265562     mae:3.8054067361551898     r2:0.9346151280051749    n_nonzero:15
# alpha: 0.5     rmse:7.779324761034483     mae:3.985484815338541     r2:0.9323038021230402    n_nonzero:5
# alpha: 1.0     rmse:8.126469412848456     mae:4.45794270710071     r2:0.9261272471652273    n_nonzero:3
# alpha: 2.0     rmse:8.918651156691286     mae:5.4228495032856046     r2:0.9110227810146102    n_nonzero:1
# alpha: 5.0     rmse:13.008631918991508     mae:8.912729234001132     r2:0.8107030032239129    n_nonzero:1
# alpha: 10.0     rmse:22.040984863404873     mae:15.427592599966063     r2:0.45657143186554927    n_nonzero:1

# %%
lasso = Lasso(alpha=0.001)

start = time.time()
lasso.fit(X_train, y_train)
training_time = time.time() - start
# Out:
# d:\projects\pm25-forecasting\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.787e+04, tolerance: 3.239e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
start = time.time()
y_pred = lasso.predict(X_test)
inference_time = (time.time() - start) / len(X_test)

nonzero_coeff = np.sum(lasso.coef_ != 0)

rmse = root_mean_squared_error(y_test, y_pred)
mae  = mean_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print(f"n             : {nonzero_coeff} / {X_train.shape[1]}")
print(f"RMSE          : {rmse:.4f}")
print(f"MAE           : {mae:.4f}")
print(f"R²            : {r2:.4f}")
print(f"Training time : {training_time:.2f}s")
print(f"Inference time: {inference_time*1000_000:.4f}µs")
# Out:
# n             : 117 / 129
# RMSE          : 6.7130
# MAE           : 3.6135
# R²            : 0.9496
# Training time : 83.70s
# Inference time: 2.2826µs
