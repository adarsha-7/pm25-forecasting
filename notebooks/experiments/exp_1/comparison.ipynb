# %%
import matplotlib.pyplot as plt

models          = ['Lag 1 hr', 'Lag 24 hr', 'Linear Reg', 'SVR', 'Decision Tree', 'Random Forest', 'XGBoost']
rmse            = [ 7.9040, 7.9284, 6.7695, 6.9521, 10.4001, 8.8816, 8.7818]
mae             = [3.8815, 3.8999, 3.6976, 3.0115,  4.8170,  4.1286, 4.4337]
r2              = [0.9301, 0.9298, 0.9487, 0.9459,  0.8790,  0.9118, 0.9137]
training_times  = [0.09,  17.23,    1.09,    5.31,   1.21]
inference_times = [1.4158, 1.4251,  1.7896, 32.1967, 3.2068]

# %%
import numpy as np

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

axes[0].bar(models, rmse)
axes[0].set_title('RMSE (lower is better)')
axes[0].tick_params(axis='x', rotation=15)
axes[0].set_yticks(np.arange(0, 12, 1))
axes[0].grid(True, axis='y')

axes[1].bar(models, mae)
axes[1].set_title('MAE (lower is better)')
axes[1].tick_params(axis='x', rotation=15)
axes[1].set_yticks(np.arange(0, 5, 0.5))
axes[1].grid(True, axis='y')

axes[2].bar(models, r2)
axes[2].set_title('R² (higher is better)')
axes[2].set_ylim(0.85, 0.95)
axes[2].tick_params(axis='x', rotation=15)
axes[2].set_yticks(np.arange(0.85, 1, 0.01))
axes[2].grid(True, axis='y')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].bar(models[2:7], training_times)
axes[0].set_title('Training Time (lower is better)')
axes[0].set_ylabel('Seconds')
axes[0].tick_params(axis='x', rotation=30)
axes[0].set_yticks(np.arange(0, 18, 1))
axes[0].grid(True, axis='y')

axes[1].bar(models[2:7], inference_times)
axes[1].set_title('Inference Time per Sample (lower is better)')
axes[1].set_ylabel('Microseconds (µs)')
axes[1].tick_params(axis='x', rotation=20)
axes[1].set_yticks(np.arange(0, 34, 2))
axes[1].grid(True, axis='y')

plt.tight_layout()
plt.show()
