# %%
import pandas as pd
from sklearn.linear_model import Lasso
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
import time

# %%
X_train = pd.read_csv("../../../data/processed/24_hour_prediction/X_train_linear.csv")
X_test  = pd.read_csv("../../../data/processed/24_hour_prediction/X_test_linear.csv")
y_train = pd.read_csv("../../../data/processed/24_hour_prediction/y_train.csv").squeeze()
y_test  = pd.read_csv("../../../data/processed/24_hour_prediction/y_test.csv").squeeze()

# %%
import numpy as np

alphas = [0.0001, 0.001, 0.01, 0.05, 0.1, 0.25, 0.5, 1.0, 2.0, 5.0, 10.0]

results = []
for alpha in alphas:
    lasso = Lasso(alpha=alpha)
    lasso.fit(X_train, y_train)
    y_pred = lasso.predict(X_test)

    rmse = root_mean_squared_error(y_test, y_pred)
    mae  = mean_absolute_error(y_test, y_pred)
    r2   = r2_score(y_test, y_pred)

    n_nonzero = np.sum(lasso.coef_ != 0)

    results.append({
        "alpha": alpha,
        "rmse": rmse,
        "mae": mae,
        "r2": r2,
        "n_nonzero_coefs": n_nonzero,
    })
# Out:
# d:\projects\pm25-forecasting\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.026e+05, tolerance: 3.165e+02
#   model = cd_fast.enet_coordinate_descent(
# d:\projects\pm25-forecasting\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.420e+04, tolerance: 3.165e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
for result in results:
    print(f"alpha: {result["alpha"]}     rmse:{result["rmse"]}     mae:{result["mae"]}     r2:{result["r2"]}    n_nonzero:{result["n_nonzero_coefs"]}")
# Out:
# alpha: 0.0001     rmse:17.743178510350997     mae:11.08215171819735     r2:0.6480439743488846    n_nonzero:126
# alpha: 0.001     rmse:17.660039862852013     mae:11.041719626358594     r2:0.6513345453048541    n_nonzero:113
# alpha: 0.01     rmse:17.203986780827936     mae:10.800931549001382     r2:0.6691099092257933    n_nonzero:81
# alpha: 0.05     rmse:16.4495783187253     mae:10.387900632336576     r2:0.6974932290177709    n_nonzero:45
# alpha: 0.1     rmse:16.114908049773625     mae:10.20488636919581     r2:0.7096771458650619    n_nonzero:33
# alpha: 0.25     rmse:15.771223714083618     mae:10.02617902076392     r2:0.7219285858237419    n_nonzero:18
# alpha: 0.5     rmse:15.653929915533542     mae:9.98976787679325     r2:0.7260493524703971    n_nonzero:13
# alpha: 1.0     rmse:15.460799272787368     mae:9.984381269966995     r2:0.7327673953627699    n_nonzero:7
# alpha: 2.0     rmse:15.164143446764228     mae:10.061133716619777     r2:0.7429241211634696    n_nonzero:4
# alpha: 5.0     rmse:19.092622374224593     mae:12.95642151434213     r2:0.5924726814927466    n_nonzero:1
# alpha: 10.0     rmse:27.643669046588137     mae:19.21526528687145     r2:0.14568716549430905    n_nonzero:1

# %%
lasso = Lasso(alpha=2)

start = time.time()
lasso.fit(X_train, y_train)
training_time = time.time() - start

# %%
import numpy as np

start = time.time()
y_pred = lasso.predict(X_test)
inference_time = (time.time() - start) / len(X_test)

nonzero_coeff = np.sum(lasso.coef_ != 0)

rmse = root_mean_squared_error(y_test, y_pred)
mae  = mean_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print(f"n             : {nonzero_coeff} / {X_train.shape[1]}")
print(f"RMSE          : {rmse:.4f}")
print(f"MAE           : {mae:.4f}")
print(f"R²            : {r2:.4f}")
print(f"Training time : {training_time:.2f}s")
print(f"Inference time: {inference_time*1000_000:.4f}µs")
# Out:
# n             : 4 / 129
# RMSE          : 15.1641
# MAE           : 10.0611
# R²            : 0.7429
# Training time : 0.77s
# Inference time: 2.5751µs
