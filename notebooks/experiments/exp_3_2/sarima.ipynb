# %%
import pandas as pd
import numpy as np
from pmdarima import auto_arima
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

data = pd.read_csv("../../../data/raw/kathmandu_full_raw_2023_2024.csv")
data["time"] = pd.to_datetime(data["time"])
data = data.sort_values("time").reset_index(drop=True)
data = data.set_index("time")
data.index.freq = "h"

split = int(np.ceil(0.8 * len(data)))
train = data.iloc[:split]
test  = data.iloc[split:]

# --- Train ---
model = auto_arima(
    train["pm2_5"],
    seasonal=True, m=24, stepwise=True,
    information_criterion="aic",
    max_p=2, max_q=2,
    max_P=1, max_D=1, max_Q=1,
)

# --- Rolling 72-hour-ahead evaluation ---
HORIZON = 72
test_pm25 = test["pm2_5"].reset_index(drop=True)

preds = []
for i in range(len(test_pm25) - HORIZON + 1):
    forecast = np.asarray(model.predict(n_periods=HORIZON))   # <-- fix applied here
    preds.append(forecast[-1])
    model.update(test_pm25.iloc[[i]])

preds = np.array(preds)
true = test_pm25.iloc[HORIZON - 1 : HORIZON - 1 + len(preds)].values

rmse = root_mean_squared_error(true, preds)
mae  = mean_absolute_error(true, preds)
r2   = r2_score(true, preds)

print(f"RMSE : {rmse:.4f}")
print(f"MAE  : {mae:.4f}")
print(f"R2   : {r2:.4f}")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 17
#      13 train = data.iloc[:split]
#      14 test  = data.iloc[split:]
#      15
#      16 # --- Train ---
# ---> 17 model = auto_arima(
#      18     train["pm2_5"],
#      19     seasonal=True, m=24, stepwise=True,
#      20     information_criterion="aic",
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\pmdarima\arima\auto.py:701, in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     669     # init the stepwise model wrapper
#     670     search = solvers._StepwiseFitWrapper(
#     671         y,
#     672         X=X,
#    (...)    698         **sarimax_kwargs,
#     699     )
# --> 701 sorted_res = search.solve()
#     702 return _return_wrapper(sorted_res, return_valid_fits, start, trace)
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\pmdarima\arima\_auto_solvers.py:353, in _StepwiseFitWrapper.solve(self)
#     348     P += 1
#     349     continue
#     351 if Q < max_Q and \
#     352         self.k < self.max_k and \
# --> 353         self._do_fit((p, d, q), (P, D, Q + 1, m)):
#     354     Q += 1
#     355     continue
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\pmdarima\arima\_auto_solvers.py:235, in _StepwiseFitWrapper._do_fit(self, order, seasonal_order, constant)
#     230 if (order, seasonal_order, constant) not in self.results_dict:
#     231
#     232     # increment the number of fits
#     233     self.k += 1
# --> 235     fit, fit_time, new_ic = self._fit_arima(
#     236         order=order,
#     237         seasonal_order=seasonal_order,
#     238         with_intercept=constant)
#     240     # use the orders as a key to be hashed for
#     241     # the dictionary (pointing to fit)
#     242     self.results_dict[(order, seasonal_order, constant)] = fit
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\pmdarima\arima\_auto_solvers.py:508, in _fit_candidate_model(y, X, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, information_criterion, **kwargs)
#     500 fit = ARIMA(order=order, seasonal_order=seasonal_order,
#     501             start_params=start_params, trend=trend, method=method,
#     502             maxiter=maxiter, suppress_warnings=suppress_warnings,
#     503             out_of_sample_size=out_of_sample_size, scoring=scoring,
#     504             scoring_args=scoring_args,
#     505             with_intercept=with_intercept, **kwargs)
#     507 try:
# --> 508     fit.fit(y, X=X, **fit_params)
#     510 # for non-stationarity errors or singular matrices, return None
#     511 except (LinAlgError, ValueError) as v:
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\pmdarima\arima\arima.py:610, in ARIMA.fit(self, y, X, **fit_args)
#     607         X = safe_indexing(X, slice(0, n_exog - cv))
#     609 # Internal call
# --> 610 self._fit(y, X, **fit_args)
#     612 # now make a forecast if we're validating to compute the
#     613 # out-of-sample score
#     614 if cv_samples is not None:
#     615     # get the predictions (use self.predict, which calls forecast
#     616     # from statsmodels internally)
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\pmdarima\arima\arima.py:531, in ARIMA._fit(self, y, X, **fit_args)
#     529     with warnings.catch_warnings(record=False):
#     530         warnings.simplefilter('ignore')
# --> 531         fit, self.arima_res_ = _fit_wrapper()
#     532 else:
#     533     fit, self.arima_res_ = _fit_wrapper()
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\pmdarima\arima\arima.py:517, in ARIMA._fit.<locals>._fit_wrapper()
#     514 _maxiter = fit_args.pop("maxiter", _maxiter)
#     516 disp = fit_args.pop("disp", 0)
# --> 517 fitted = arima.fit(
#     518     start_params=start_params,
#     519     method=method,
#     520     maxiter=_maxiter,
#     521     disp=disp,
#     522     **fit_args,
#     523 )
#     525 return arima, fitted
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:729, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     727 else:
#     728     func = self.smooth
# --> 729 res = func(mlefit.params, transformed=False, includes_fixed=False,
#     730            cov_type=cov_type, cov_kwds=cov_kwds)
#     732 res.mlefit = mlefit
#     733 res.mle_retvals = mlefit.mle_retvals
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:887, in MLEModel.smooth(self, params, transformed, includes_fixed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     884     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     886 # Get the state space output
# --> 887 result = self.ssm.smooth(complex_step=complex_step, **kwargs)
#     889 # Wrap in a results object
#     890 return self._wrap_results(params, result, return_ssm, cov_type,
#     891                           cov_kwds, results_class,
#     892                           results_wrapper_class)
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\statsmodels\tsa\statespace\kalman_smoother.py:403, in KalmanSmoother.smooth(self, smoother_output, smooth_method, results, run_filter, prefix, complex_step, update_representation, update_filter, update_smoother, **kwargs)
#     377 """
#     378 Apply the Kalman smoother to the statespace model.
#     379
#    (...)    399 SmootherResults object
#     400 """
#     402 # Run the filter
# --> 403 kfilter = self._filter(**kwargs)
#     405 # Create the results object
#     406 results = self.results_class(self)
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:913, in KalmanFilter._filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     907 def _filter(self, filter_method=None, inversion_method=None,
#     908             stability_method=None, conserve_memory=None,
#     909             filter_timing=None, tolerance=None, loglikelihood_burn=None,
#     910             complex_step=False):
#     911     # Initialize the filter
#     912     prefix, dtype, create_filter, create_statespace = (
# --> 913         self._initialize_filter(
#     914             filter_method, inversion_method, stability_method,
#     915             conserve_memory, filter_timing, tolerance, loglikelihood_burn
#     916         )
#     917     )
#     918     kfilter = self._kalman_filters[prefix]
#     920     # Initialize the state
#
# File d:\projects\pm25-forecasting\.venv\Lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:501, in KalmanFilter._initialize_filter(self, filter_method, inversion_method, stability_method, conserve_memory, tolerance, filter_timing, loglikelihood_burn)
#     499     # Setup the filter
#     500     cls = self.prefix_kalman_filter_map[prefix]
# --> 501     self._kalman_filters[prefix] = cls(
#     502         self._statespaces[prefix], filter_method, inversion_method,
#     503         stability_method, conserve_memory, filter_timing, tolerance,
#     504         loglikelihood_burn
#     505     )
#     506 # Otherwise, update the filter parameters
#     507 else:
#     508     kalman_filter = self._kalman_filters[prefix]
#
# File statsmodels/tsa/statespace/_kalman_filter.pyx:1720, in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.__init__()
# -> 1720 'Could not get source, probably due dynamically evaluated source code.'
#
# File statsmodels/tsa/statespace/_kalman_filter.pyx:2131, in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.set_filter_method()
# -> 2131 'Could not get source, probably due dynamically evaluated source code.'
#
# File statsmodels/tsa/statespace/_kalman_filter.pyx:1882, in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.allocate_arrays()
# -> 1882 'Could not get source, probably due dynamically evaluated source code.'
#
# MemoryError: Unable to allocate 78.1 MiB for an array with shape (27, 27, 14036) and data type float64
