# %%
import matplotlib.pyplot as plt

models                = ['Current PM 2.5', 'Linear Reg without features', 'ARIMA', 'SARIMA']
rmse                  = [12.5561, 13.8275, 13.2173, 15.8475]
mae                   = [8.3856, 8.9266, 8.9220, 10.7485]
r2                    = [0.8239, 0.7862,  0.8047, 0.7193]

# %%
import numpy as np

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

axes[0].bar(models, rmse)
axes[0].set_title('RMSE (lower is better)')
axes[0].tick_params(axis='x', rotation=45)
axes[0].set_yticks(np.arange(0, 20, 2))
axes[0].grid(True, axis='y')

axes[1].bar(models, mae)
axes[1].set_title('MAE (lower is better)')
axes[1].tick_params(axis='x', rotation=45)
axes[1].set_yticks(np.arange(0, 15, 1))
axes[1].grid(True, axis='y')

axes[2].bar(models, r2)
axes[2].set_title('R² (higher is better)')
axes[2].tick_params(axis='x', rotation=45)
axes[2].set_ylim((0.9,1))
axes[2].set_yticks(np.arange(0.7, 1, 0.02))
axes[2].grid(True, axis='y')

plt.tight_layout()
plt.show()
