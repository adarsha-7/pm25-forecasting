# %%
import matplotlib.pyplot as plt

models = ['Current PM2.5', 'Linear Reg (No Features)', 'Linear Reg', 'Lasso', 'Random Forest', 'XGBoost', 'LSTM']

rmse = [20.2519, 20.9040, 26.9295, 23.6029, 24.3310, 24.6333, 27.4036]
mae = [13.5863, 13.5296, 16.7360, 15.3649, 15.6441, 16.1151, 18.4868]
r2 = [0.5442, 0.5116, 0.1894, 0.3773, 0.3383, 0.3218, 0.1607]

# %%
import numpy as np

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

axes[0].bar(models, rmse)
axes[0].set_title('RMSE (lower is better)')
axes[0].tick_params(axis='x', rotation=45)
axes[0].set_yticks(np.arange(0, 30, 2))
axes[0].grid(True, axis='y')

axes[1].bar(models, mae)
axes[1].set_title('MAE (lower is better)')
axes[1].tick_params(axis='x', rotation=45)
axes[1].set_yticks(np.arange(0, 20, 2))
axes[1].grid(True, axis='y')

axes[2].bar(models, r2)
axes[2].set_title('R² (higher is better)')
axes[2].set_ylim(0.85, 0.95)
axes[2].tick_params(axis='x', rotation=45)
axes[2].set_yticks(np.arange(0, 1, 0.1))
axes[2].grid(True, axis='y')

plt.tight_layout()
plt.show()
