# %%
import pandas as pd

path = "../../data/raw/kathmandu_full_raw_2023_2024.csv"

data = pd.read_csv(path)

# %%
data.shape
# Out:
# (17544, 12)

# %%
data.sample(5)
# Out:
#                   time  pm2_5  pm10  carbon_monoxide  nitrogen_dioxide  \
# 6593   10/2/2023 17:00   14.6  21.0              385              10.1
# 8172   12/7/2023 12:00   52.7  76.6              455               3.0
# 13038   6/27/2024 6:00   17.7  25.5              440              10.9
# 13418   7/13/2024 2:00   20.1  28.6              371               9.6
# 5464   8/16/2023 16:00   25.7  41.0              219               1.9
#
#        sulphur_dioxide  ozone  temperature_2m  relative_humidity_2m  \
# 6593               3.2     82            21.3                    87
# 8172               7.7    119            16.5                    67
# 13038              6.1     70            21.7                    95
# 13418              4.9     79            20.8                    98
# 5464               2.6    111            24.1                    85
#
#        wind_speed_10m  wind_direction_10m  surface_pressure
# 6593              3.8                 343             870.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time                  17544 non-null  str
#  1   pm2_5                 17544 non-null  float64
#  2   pm10                  17544 non-null  float64
#  3   carbon_monoxide       17544 non-null  int64
#  4   nitrogen_dioxide      17544 non-null  float64
#  5   sulphur_dioxide       17544 non-null  float64
#  6   ozone                 17544 non-null  int64
#  7   temperature_2m        17544 non-null  float64
#  8   relative_humidity_2m  17544 non-null  int64
#  9   wind_speed_10m        17544 non-null  float64
#  10  wind_direction_10m    17544 non-null  int64
#  11  surface_pressure      17544 non-null  float64
# dtypes: float64(7), int64(4), str(1)
# memory usage: 1.6 MB

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#               pm2_5          pm10  carbon_monoxide  nitrogen_dioxide  \
# count  17544.000000  17544.000000     17544.000000      17544.000000
# mean      30.664689     43.707974       612.107045         12.572458
# std       19.408556     24.614492       421.671717         11.520046
# min        0.400000      0.500000        87.000000          0.000000
# 25%       17.500000     25.575000       314.000000          3.500000
# 50%       26.100000     38.400000       477.000000          9.500000
# 75%       39.000000     57.500000       764.000000         18.300000
# max      164.400000    180.200000      3153.000000        107.300000
#
#        sulphur_dioxide         ozone  temperature_2m  relative_humidity_2m  \
# count     17544.000000  17544.000000    17544.000000          17544.000000
# mean          6.137454     96.054891       18.154799             74.586069
# std           4.086209     35.692174        5.896066             20.973804
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(data["pm2_5"], bins=50)
plt.title("PM2.5 Distribution")
plt.xlabel("PM2.5")
plt.ylabel("Frequency")
plt.show()
